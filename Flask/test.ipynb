# %%
import pickle
model2 = pickle.load(open("height.pkl", "rb"))

# %%
model2.predict([[50]])
# Out:
# c:\Users\ABDULLAH AL MASUM\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[75.13148931]])
