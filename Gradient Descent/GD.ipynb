# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, FunctionTransformer
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#            x          y
# 0  48.955889  60.723602
# 1  44.687196  82.892504
# 2  60.297327  97.379897
# 3  45.618644  48.847153
# 4  38.816818  56.877213

# %% [markdown]
# # Use sklearn

# %%
x1 = df[['x']]
y1 = df[['y']]

# %%
lr = LinearRegression()
model = lr.fit(x1, y1)

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [9.90860619]
# [[1.28735737]]

# %% [markdown]
# # Use GD

# %%
x2 = df['x']
y2 = df['y']

# %%
m = 0
c = 0
learning_rate = 0.0001
iteration = 1000
n = (len(x2))

# %%
for i in range(iteration):
  pred = (m * x2) + c
  Dm = (-2/n) * sum(x2 * (y2 - pred))
  Dc = (-2/n) * sum(y2 - pred)
  m = m - learning_rate * Dm
  c = c - learning_rate * Dc

# %%
m
# Out:
# 1.4796491688881985

# %%
c
# Out:
# 0.10148121497503651

# %%
m * 60.297327 + c
# Out:
# 89.32037099670498

# %%
model.predict(x1)
# Out:
# array([[ 72.93233015],
#        [ 67.4369976 ],
#        [ 87.5328143 ],
#        [ 68.63610346],
#        [ 59.87972233],
#        [ 78.68799611],
#        [ 89.12016608],
#        [ 71.02672076],
#        [ 77.55925457],
#        [ 68.38003053],
#        [ 79.87858393],
#        [ 66.7635208 ],
#        [ 84.79221567],
#        [ 82.93679557],
#        [ 86.90958017],
#        [ 80.89630884],
#        [ 77.12384746],
#        [ 60.50119301],
#        [ 71.83698614],
#        [ 95.11855442],
#        [ 94.12244253],
#        [ 71.03389003],
#        [ 63.43131613],
#        [ 76.65188966],
#        [ 86.34007147],
#        [ 83.68706149],
#        [ 91.80456781],
#        [ 70.07662499],
#        [ 74.99322397],
#        [ 77.13955245],
#        [ 55.69711434],
#        [ 64.53951754],
#        [ 84.78715557],
#        [ 83.93738064],
#        [ 68.40680832],
#        [ 89.59116463],
#        [ 52.51219438],
#        [ 56.81477157],
#        [ 58.41063815],
#        [ 67.26759701],
#        [ 65.67471659],
#        [ 74.37063926],
#        [ 66.38576271],
#        [ 91.00887733],
#        [ 51.96534045],
#        [ 61.61775966],
#        [ 78.8788771 ],
#        [ 53.50395291],
#        [ 93.20981805],
#        [ 58.9824426 ],
#        [ 67.19927655],
#        [ 62.17472114],
#        [ 63.61802638],
#        [ 75.67793657],
#        [ 80.81379887],
#        [ 63.17652739],
#        [ 90.36161551],
#        [ 73.25159345],
#        [ 62.8224509 ],
#        [ 62.92457814],
#        [ 74.51642457],
#        [ 77.33838496],
#        [ 74.45089294],
#        [ 53.22136644],
#        [ 60.83376187],
#        [ 82.16847592],
#        [ 83.75406676],
#        [ 87.49662352],
#        [ 55.83906331],
#        [ 50.57380142],
#        [ 78.98940282],
#        [ 70.00531729],
#        [ 65.40377626],
#        [100.46914509],
#        [ 67.18681212],
#        [ 83.93749094],
#        [ 57.45081249],
#        [ 81.75052832],
#        [ 60.05731525],
#        [ 83.1608043 ],
#        [ 83.11920458],
#        [ 54.10760731],
#        [ 85.92672573],
#        [ 84.30270224],
#        [ 79.78936212],
#        [ 75.67804628],
#        [ 74.64058615],
#        [ 66.82491777],
#        [ 58.83525128],
#        [ 52.31477581],
#        [ 79.0289341 ],
#        [ 98.43468101],
#        [ 69.42438164],
#        [ 97.86003886],
#        [ 74.31531985],
#        [ 73.297781  ],
#        [ 74.32742307],
#        [ 71.8946819 ],
#        [ 42.2579461 ]])

# %% [markdown]
# # Best fit for sklean

# %%
y_pred = model.predict(x1)

# %%
fig, axs = plt.subplots(1, 2, figsize = (12, 8))
axs[0].scatter(x1, y1)
axs[0].plot(x1, y_pred, color = 'red')

axs[1].scatter(x2, y2)
axs[1].plot(x2, m * x2 + c, color = 'grey')
