# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah-621/Machine-Learning/blob/main/Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **-> Label Encoding**
# # **-> Ordinal Encoding**
# # **-> One Hot Encoding**

# %% [markdown]
# # Ordinal Encoding

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# %%
# Sample DataFrame
data = {'Name': ['A', 'B', 'C', 'D'],
        'Education_Level': ['Secondary','Primary', 'Higher Secondary', 'Graduate']}

df = pd.DataFrame(data)

# Define order of categories
education_order = [['Primary', 'Secondary', 'Higher Secondary', 'Graduate']]

encoder = OrdinalEncoder(categories = education_order)

df['Education_Level_Encoded'] = encoder.fit_transform(df[['Education_Level']])


df
# Out:
#   Name   Education_Level  Education_Level_Encoded
# 0    A         Secondary                      1.0
# 1    B           Primary                      0.0
# 2    C  Higher Secondary                      2.0
# 3    D          Graduate                      3.0

# %%
from sklearn.preprocessing import OrdinalEncoder

df = pd.read_csv("/content/StudentsPerformance.csv")
df['parental level of education'].unique()

education_order = [['high school','some high school','some college',"associate's degree","bachelor's degree","master's degree"]]

encoder = OrdinalEncoder(categories = education_order)

# a = encoder.fit(df[['parental level of education']])
# a
# df['parental level of education'] = encoder.transform(df[['parental level of education']])


df['parental level of education Encoded'] = encoder.fit_transform(df[['parental level of education']])


df['parental level of education Encoded']  = df['parental level of education Encoded']  + 1
df
# Out:
#      gender race/ethnicity  ... writing score parental level of education Encoded
# 0    female        group B  ...            74                                 5.0
# 1    female        group C  ...            88                                 3.0
# 2    female        group B  ...            93                                 6.0
# 3      male        group A  ...            44                                 4.0
# 4      male        group C  ...            75                                 3.0
# ..      ...            ...  ...           ...                                 ...
# 995  female        group E  ...            95                                 6.0
# 996    male        group C  ...            55                                 1.0
# 997  female        group C  ...            65                                 1.0
# 998  female        group D  ...            77                                 3.0
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Sample DataFrame
data = {'Name': ['A', 'B', 'C', 'D'],
        'Gender': ['Male', 'Female', 'Female', 'Male']}

df_temp = pd.DataFrame(data)

# gender_order = df[['Male', "Female"]]
label = LabelEncoder()

df_temp['Gender_Encoded'] = label.fit_transform(df_temp['Gender'])

df_temp
# Out:
#   Name  Gender  Gender_Encoded
# 0    A    Male               1
# 1    B  Female               0
# 2    C  Female               0
# 3    D    Male               1

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender_Encoded'] = le.fit_transform(df['gender'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3660830973.py in <cell line: 0>()
#       3 le = LabelEncoder()
#       4
# ...

# %% [markdown]
# # One Hot Encoding

# %%
import pandas as pd

# Sample DataFrame
data = {'Name': ['A', 'B', 'C', 'D', 'E'],
        'Color': ['Red', 'Blue', 'Green', 'Red', 'Yellow']}

df_color = pd.DataFrame(data)
df_color
# Out:
#   Name   Color
# 0    A     Red
# 1    B    Blue
# 2    C   Green
# 3    D     Red
# 4    E  Yellow

# %%
# Using Pandas get_dummies

df_encoded = pd.get_dummies(df_color, columns = ['Color'])
df_encoded
# Out:
#   Name  Color_Blue  Color_Green  Color_Red  Color_Yellow
# 0    A       False        False       True         False
# 1    B        True        False      False         False
# 2    C       False         True      False         False
# 3    D       False        False       True         False
# 4    E       False        False      False          True

# %%
# Using SKlearn

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output = False)
encoder_array = encoder.fit_transform(df[['Color']])

# type(encoder_array)
# columns=encoder.get_feature_names_out(['Color'])
# columns

df_encoded = pd.DataFrame(encoder_array, columns = encoder.get_feature_names_out(["Color"]))

df_encoded['Name'] = df['Name']
df_encoded
# Out:
#    Color_Blue  Color_Green  Color_Red  Color_Yellow Name
# 0         0.0          0.0        1.0           0.0    A
# 1         1.0          0.0        0.0           0.0    B
# 2         0.0          1.0        0.0           0.0    C
# 3         0.0          0.0        1.0           0.0    D
# 4         0.0          0.0        0.0           1.0    E

# %%
df
# Out:
#      gender race/ethnicity  ... writing score parental level of education Encoded
# 0    female        group B  ...            74                                 5.0
# 1    female        group C  ...            88                                 3.0
# 2    female        group B  ...            93                                 6.0
# 3      male        group A  ...            44                                 4.0
# 4      male        group C  ...            75                                 3.0
# ..      ...            ...  ...           ...                                 ...
# 995  female        group E  ...            95                                 6.0
# 996    male        group C  ...            55                                 1.0
# 997  female        group C  ...            65                                 1.0
# 998  female        group D  ...            77                                 3.0
# ...
